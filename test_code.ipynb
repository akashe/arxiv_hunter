# %%
import os
os.getcwd()
# Out:
# '/home/ec2-user/SageMaker/arxiv_hunter'

# %%
# !pip install --upgrade pip
# Out:
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Requirement already satisfied: pip in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (22.0.4)
# Collecting pip
#   Downloading pip-22.3.1-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 20.1 MB/s eta 0:00:00:00:01
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 22.0.4
#     Uninstalling pip-22.0.4:
#       Successfully uninstalled pip-22.0.4
# Successfully installed pip-22.3.1

# %%
# !pip install --no-cache-dir -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Collecting en-core-web-sm@ https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.4.0/en_core_web_sm-3.4.0-py3-none-any.whl
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.4.0/en_core_web_sm-3.4.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 256.7 MB/s eta 0:00:00a 0:00:01
# Collecting absl-py==1.2.0
#   Downloading absl_py-1.2.0-py3-none-any.whl (123 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.4/123.4 kB 31.4 MB/s eta 0:00:00
# Collecting aiohttp==3.8.3
#   Downloading aiohttp-3.8.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 57.8 MB/s eta 0:00:00
# Requirement already satisfied: aiosignal==1.2.0 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from -r requirements.txt (line 3)) (1.2.0)
# Collecting async-timeout==4.0.2
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting attrs==22.1.0
#   Downloading attrs-22.1.0-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 234.8 MB/s eta 0:00:00
# Collecting blis==0.7.8
#   Downloading blis-0.7.8-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 134.5 MB/s eta 0:00:00a 0:00:01
# Collecting cachetools==5.2.0
#   Downloading cachetools-5.2.0-py3-none-any.whl (9.3 kB)
# Collecting catalogue==2.0.8
#   Downloading catalogue-2.0.8-py3-none-any.whl (17 kB)
# Collecting certifi==2022.9.24
#   Downloading certifi-2022.9.24-py3-none-any.whl (161 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.1/161.1 kB 318.2 MB/s eta 0:00:00
# Collecting charset-normalizer==2.1.1
#   Downloading charset_normalizer-2.1.1-py3-none-any.whl (39 kB)
# Collecting click==8.1.3
#   Downloading click-8.1.3-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.6/96.6 kB 300.5 MB/s eta 0:00:00
# Collecting confection==0.0.2
#   Downloading confection-0.0.2-py3-none-any.whl (32 kB)
# Requirement already satisfied: cymem==2.0.6 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from -r requirements.txt (line 13)) (2.0.6)
# Collecting docker-pycreds==0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting feedparser==6.0.10
#   Downloading feedparser-6.0.10-py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.1/81.1 kB 289.8 MB/s eta 0:00:00
# Collecting filelock==3.8.0
#   Downloading filelock-3.8.0-py3-none-any.whl (10 kB)
# Collecting frozenlist==1.3.1
#   Downloading frozenlist-1.3.1-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (161 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.3/161.3 kB 324.5 MB/s eta 0:00:00
# Collecting fsspec==2022.8.2
#   Downloading fsspec-2022.8.2-py3-none-any.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.8/140.8 kB 319.4 MB/s eta 0:00:00
# Collecting gitdb==4.0.9
#   Downloading gitdb-4.0.9-py3-none-any.whl (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 kB 268.5 MB/s eta 0:00:00
# Collecting GitPython==3.1.27
#   Downloading GitPython-3.1.27-py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.2/181.2 kB 309.1 MB/s eta 0:00:00
# Collecting google-auth==2.12.0
#   Downloading google_auth-2.12.0-py2.py3-none-any.whl (169 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.8/169.8 kB 328.7 MB/s eta 0:00:00
# Collecting google-auth-oauthlib==0.4.6
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting grpcio==1.49.1
#   Downloading grpcio-1.49.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 243.9 MB/s eta 0:00:00
# Collecting huggingface-hub==0.10.0
#   Downloading huggingface_hub-0.10.0-py3-none-any.whl (163 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.5/163.5 kB 289.3 MB/s eta 0:00:00
# Collecting idna==3.4
#   Downloading idna-3.4-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.5/61.5 kB 234.6 MB/s eta 0:00:00
# Collecting importlib-metadata==5.0.0
#   Downloading importlib_metadata-5.0.0-py3-none-any.whl (21 kB)
# Collecting Jinja2==3.1.2
#   Downloading Jinja2-3.1.2-py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.1/133.1 kB 322.9 MB/s eta 0:00:00
# Requirement already satisfied: langcodes==3.3.0 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from -r requirements.txt (line 29)) (3.3.0)
# Collecting Markdown==3.4.1
#   Downloading Markdown-3.4.1-py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.3/93.3 kB 269.6 MB/s eta 0:00:00
# Collecting MarkupSafe==2.1.1
#   Downloading MarkupSafe-2.1.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Collecting multidict==6.0.2
#   Downloading multidict-6.0.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.3/121.3 kB 200.7 MB/s eta 0:00:00
# Collecting murmurhash==1.0.8
#   Downloading murmurhash-1.0.8-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (21 kB)
# Collecting numpy==1.23.3
#   Downloading numpy-1.23.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 245.7 MB/s eta 0:00:00a 0:00:01
# Collecting oauthlib==3.2.1
#   Downloading oauthlib-3.2.1-py3-none-any.whl (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.7/151.7 kB 327.9 MB/s eta 0:00:00
# Requirement already satisfied: packaging==21.3 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from -r requirements.txt (line 36)) (21.3)
# Requirement already satisfied: pathtools==0.1.2 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from -r requirements.txt (line 37)) (0.1.2)
# Collecting pathy==0.6.2
#   Downloading pathy-0.6.2-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 kB 213.6 MB/s eta 0:00:00
# Collecting preshed==3.0.7
#   Downloading preshed-3.0.7-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.8/130.8 kB 317.7 MB/s eta 0:00:00
# Collecting promise==2.3
#   Downloading promise-2.3.tar.gz (19 kB)
#   Preparing metadata (setup.py) ... done
# Collecting protobuf==3.19.6
#   Downloading protobuf-3.19.6-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 205.6 MB/s eta 0:00:00
# Collecting psutil==5.9.2
#   Downloading psutil-5.9.2-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (284 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.8/284.8 kB 339.7 MB/s eta 0:00:00
# Requirement already satisfied: pyasn1==0.4.8 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from -r requirements.txt (line 43)) (0.4.8)
# Collecting pyasn1-modules==0.2.8
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 305.8 MB/s eta 0:00:00
# Collecting pydantic==1.9.2
#   Downloading pydantic-1.9.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 239.7 MB/s eta 0:00:00a 0:00:01
# Collecting pyDeprecate==0.3.2
#   Downloading pyDeprecate-0.3.2-py3-none-any.whl (10 kB)
# Collecting PyMuPDF==1.20.2
#   Downloading PyMuPDF-1.20.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 222.8 MB/s eta 0:00:00a 0:00:01
# Collecting pyparsing==3.0.9
#   Downloading pyparsing-3.0.9-py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.3/98.3 kB 276.2 MB/s eta 0:00:00
# Collecting pytorch-lightning==1.7.7
#   Downloading pytorch_lightning-1.7.7-py3-none-any.whl (708 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 708.1/708.1 kB 340.3 MB/s eta 0:00:00
# Collecting PyYAML==6.0
#   Downloading PyYAML-6.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (701 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 701.2/701.2 kB 353.3 MB/s eta 0:00:00
# Collecting regex==2022.9.13
#   Downloading regex-2022.9.13-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (772 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 772.3/772.3 kB 352.4 MB/s eta 0:00:00
# Collecting requests==2.28.1
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 259.5 MB/s eta 0:00:00
# Collecting requests-oauthlib==1.3.1
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting rsa==4.9
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Collecting scipy==1.9.1
#   Downloading scipy-1.9.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (43.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.4/43.4 MB 229.7 MB/s eta 0:00:00a 0:00:01
# Collecting sentry-sdk==1.9.9
#   Downloading sentry_sdk-1.9.9-py2.py3-none-any.whl (162 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.1/162.1 kB 325.5 MB/s eta 0:00:00
# Collecting setproctitle==1.3.2
#   Downloading setproctitle-1.3.2-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (31 kB)
# Collecting sgmllib3k==1.0.0
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
#   Preparing metadata (setup.py) ... done
# Collecting shortuuid==1.0.9
#   Downloading shortuuid-1.0.9-py3-none-any.whl (9.4 kB)
# Requirement already satisfied: six==1.16.0 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from -r requirements.txt (line 60)) (1.16.0)
# Requirement already satisfied: smart-open==5.2.1 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from -r requirements.txt (line 61)) (5.2.1)
# Collecting smmap==5.0.0
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Collecting spacy==3.4.1
#   Downloading spacy-3.4.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 269.0 MB/s eta 0:00:00
# Collecting spacy-legacy==3.0.10
#   Downloading spacy_legacy-3.0.10-py2.py3-none-any.whl (21 kB)
# Collecting spacy-loggers==1.0.3
#   Downloading spacy_loggers-1.0.3-py3-none-any.whl (9.3 kB)
# Collecting srsly==2.4.4
#   Downloading srsly-2.4.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (461 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 461.4/461.4 kB 347.8 MB/s eta 0:00:00
# Collecting tensorboard==2.10.1
#   Downloading tensorboard-2.10.1-py3-none-any.whl (5.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 265.9 MB/s eta 0:00:00
# Collecting tensorboard-data-server==0.6.1
#   Downloading tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 272.8 MB/s eta 0:00:00
# Collecting tensorboard-plugin-wit==1.8.1
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.3/781.3 kB 347.9 MB/s eta 0:00:00
# Collecting thinc==8.1.2
#   Downloading thinc-8.1.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (817 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 817.8/817.8 kB 354.2 MB/s eta 0:00:00
# Collecting tokenizers==0.12.1
#   Downloading tokenizers-0.12.1-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 265.1 MB/s eta 0:00:00
# Collecting torchmetrics==0.9.3
#   Downloading torchmetrics-0.9.3-py3-none-any.whl (419 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 419.6/419.6 kB 345.5 MB/s eta 0:00:00
# Collecting tqdm==4.64.1
#   Downloading tqdm-4.64.1-py2.py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 268.6 MB/s eta 0:00:00
# Collecting transformers==4.22.2
#   Downloading transformers-4.22.2-py3-none-any.whl (4.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 310.0 MB/s eta 0:00:00
# Collecting typer==0.4.2
#   Downloading typer-0.4.2-py3-none-any.whl (27 kB)
# Collecting typing_extensions==4.3.0
#   Downloading typing_extensions-4.3.0-py3-none-any.whl (25 kB)
# Collecting urllib3==1.26.12
#   Downloading urllib3-1.26.12-py2.py3-none-any.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.4/140.4 kB 306.5 MB/s eta 0:00:00
# Collecting wandb==0.13.3
#   Downloading wandb-0.13.3-py2.py3-none-any.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 342.9 MB/s eta 0:00:00
# Collecting wasabi==0.10.1
#   Downloading wasabi-0.10.1-py3-none-any.whl (26 kB)
# Collecting Werkzeug==2.2.2
#   Downloading Werkzeug-2.2.2-py3-none-any.whl (232 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.7/232.7 kB 340.6 MB/s eta 0:00:00
# Collecting yarl==1.8.1
#   Downloading yarl-1.8.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (262 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 262.1/262.1 kB 336.8 MB/s eta 0:00:00
# Collecting zipp==3.8.1
#   Downloading zipp-3.8.1-py3-none-any.whl (5.6 kB)
# Requirement already satisfied: fsspec[http]!=2021.06.0,>=2021.05.0 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from pytorch-lightning==1.7.7->-r requirements.txt (line 49)) (2021.11.1)
# Requirement already satisfied: torch>=1.9.* in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from pytorch-lightning==1.7.7->-r requirements.txt (line 49)) (1.10.0)
# Requirement already satisfied: setuptools in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from spacy==3.4.1->-r requirements.txt (line 63)) (59.2.0)
# Requirement already satisfied: wheel>=0.26 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from tensorboard==2.10.1->-r requirements.txt (line 67)) (0.37.0)
# Collecting fsspec[http]!=2021.06.0,>=2021.05.0
#   Downloading fsspec-2022.11.0-py3-none-any.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.5/139.5 kB 313.4 MB/s eta 0:00:00
#   Downloading fsspec-2022.10.0-py3-none-any.whl (138 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.8/138.8 kB 292.3 MB/s eta 0:00:00
# Building wheels for collected packages: promise, sgmllib3k
#   Building wheel for promise (setup.py) ... done
#   Created wheel for promise: filename=promise-2.3-py3-none-any.whl size=21502 sha256=e07d63b691674e0d9643473316f7a7fc9fef5cbb52236ec3d6762d1f969af9ab
#   Stored in directory: /tmp/pip-ephem-wheel-cache-19hs42jx/wheels/6a/fe/dc/a7b3e03dfd0afb3a19691905bbafac1fbaebb704a02a4daeb2
#   Building wheel for sgmllib3k (setup.py) ... done
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6065 sha256=c60163441f487c12eb7f1be2e10d17347f5915b64a0bbd798388638a7bb055b3
#   Stored in directory: /tmp/pip-ephem-wheel-cache-19hs42jx/wheels/f2/3d/e2/03a8c2177ae48bc14ba849ffc39182eb96126a2ee08ec6dd1e
# Successfully built promise sgmllib3k
# Installing collected packages: wasabi, tokenizers, tensorboard-plugin-wit, sgmllib3k, zipp, urllib3, typing_extensions, tqdm, tensorboard-data-server, spacy-loggers, spacy-legacy, smmap, shortuuid, setproctitle, rsa, regex, PyYAML, pyparsing, PyMuPDF, pyDeprecate, pyasn1-modules, psutil, protobuf, promise, oauthlib, numpy, murmurhash, multidict, MarkupSafe, idna, grpcio, fsspec, frozenlist, filelock, feedparser, docker-pycreds, click, charset-normalizer, certifi, catalogue, cachetools, attrs, async-timeout, absl-py, yarl, Werkzeug, typer, srsly, sentry-sdk, scipy, requests, pydantic, preshed, Jinja2, importlib-metadata, google-auth, gitdb, blis, torchmetrics, requests-oauthlib, pathy, Markdown, huggingface-hub, GitPython, confection, aiohttp, wandb, transformers, thinc, google-auth-oauthlib, tensorboard, spacy, pytorch-lightning, en-core-web-sm
#   Attempting uninstall: wasabi
#     Found existing installation: wasabi 0.9.0
#     Uninstalling wasabi-0.9.0:
#       Successfully uninstalled wasabi-0.9.0
#   Attempting uninstall: zipp
#     Found existing installation: zipp 3.6.0
#     Uninstalling zipp-3.6.0:
#       Successfully uninstalled zipp-3.6.0
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.26.8
#     Uninstalling urllib3-1.26.8:
#       Successfully uninstalled urllib3-1.26.8
#   Attempting uninstall: typing_extensions
#     Found existing installation: typing_extensions 4.0.0
#     Uninstalling typing_extensions-4.0.0:
#       Successfully uninstalled typing_extensions-4.0.0
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.62.3
#     Uninstalling tqdm-4.62.3:
#       Successfully uninstalled tqdm-4.62.3
#   Attempting uninstall: spacy-loggers
#     Found existing installation: spacy-loggers 1.0.1
#     Uninstalling spacy-loggers-1.0.1:
#       Successfully uninstalled spacy-loggers-1.0.1
#   Attempting uninstall: spacy-legacy
#     Found existing installation: spacy-legacy 3.0.9
#     Uninstalling spacy-legacy-3.0.9:
#       Successfully uninstalled spacy-legacy-3.0.9
#   Attempting uninstall: rsa
#     Found existing installation: rsa 4.7.2
#     Uninstalling rsa-4.7.2:
#       Successfully uninstalled rsa-4.7.2
#   Attempting uninstall: regex
#     Found existing installation: regex 2021.11.10
#     Uninstalling regex-2021.11.10:
#       Successfully uninstalled regex-2021.11.10
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 5.4.1
#     Uninstalling PyYAML-5.4.1:
#       Successfully uninstalled PyYAML-5.4.1
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.0.6
#     Uninstalling pyparsing-3.0.6:
#       Successfully uninstalled pyparsing-3.0.6
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.8.0
#     Uninstalling psutil-5.8.0:
#       Successfully uninstalled psutil-5.8.0
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.19.4
#     Uninstalling protobuf-3.19.4:
#       Successfully uninstalled protobuf-3.19.4
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.2
#     Uninstalling numpy-1.21.2:
#       Successfully uninstalled numpy-1.21.2
#   Attempting uninstall: murmurhash
#     Found existing installation: murmurhash 1.0.6
#     Uninstalling murmurhash-1.0.6:
#       Successfully uninstalled murmurhash-1.0.6
#   Attempting uninstall: multidict
#     Found existing installation: multidict 5.2.0
#     Uninstalling multidict-5.2.0:
#       Successfully uninstalled multidict-5.2.0
#   Attempting uninstall: MarkupSafe
#     Found existing installation: MarkupSafe 2.0.1
#     Uninstalling MarkupSafe-2.0.1:
#       Successfully uninstalled MarkupSafe-2.0.1
#   Attempting uninstall: idna
#     Found existing installation: idna 3.1
#     Uninstalling idna-3.1:
#       Successfully uninstalled idna-3.1
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2021.11.1
#     Uninstalling fsspec-2021.11.1:
#       Successfully uninstalled fsspec-2021.11.1
#   Attempting uninstall: frozenlist
#     Found existing installation: frozenlist 1.2.0
#     Uninstalling frozenlist-1.2.0:
#       Successfully uninstalled frozenlist-1.2.0
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.4.0
#     Uninstalling filelock-3.4.0:
#       Successfully uninstalled filelock-3.4.0
#   Attempting uninstall: click
#     Found existing installation: click 8.0.3
#     Uninstalling click-8.0.3:
#       Successfully uninstalled click-8.0.3
#   Attempting uninstall: charset-normalizer
#     Found existing installation: charset-normalizer 2.0.7
#     Uninstalling charset-normalizer-2.0.7:
#       Successfully uninstalled charset-normalizer-2.0.7
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2021.10.8
#     Uninstalling certifi-2021.10.8:
#       Successfully uninstalled certifi-2021.10.8
#   Attempting uninstall: catalogue
#     Found existing installation: catalogue 2.0.6
#     Uninstalling catalogue-2.0.6:
#       Successfully uninstalled catalogue-2.0.6
#   Attempting uninstall: attrs
#     Found existing installation: attrs 21.2.0
#     Uninstalling attrs-21.2.0:
#       Successfully uninstalled attrs-21.2.0
#   Attempting uninstall: async-timeout
#     Found existing installation: async-timeout 4.0.1
#     Uninstalling async-timeout-4.0.1:
#       Successfully uninstalled async-timeout-4.0.1
#   Attempting uninstall: yarl
#     Found existing installation: yarl 1.7.2
#     Uninstalling yarl-1.7.2:
#       Successfully uninstalled yarl-1.7.2
#   Attempting uninstall: Werkzeug
#     Found existing installation: Werkzeug 2.0.3
#     Uninstalling Werkzeug-2.0.3:
#       Successfully uninstalled Werkzeug-2.0.3
#   Attempting uninstall: typer
#     Found existing installation: typer 0.4.0
#     Uninstalling typer-0.4.0:
#       Successfully uninstalled typer-0.4.0
#   Attempting uninstall: srsly
#     Found existing installation: srsly 2.4.2
#     Uninstalling srsly-2.4.2:
#       Successfully uninstalled srsly-2.4.2
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.7.2
#     Uninstalling scipy-1.7.2:
#       Successfully uninstalled scipy-1.7.2
#   Attempting uninstall: requests
#     Found existing installation: requests 2.26.0
#     Uninstalling requests-2.26.0:
#       Successfully uninstalled requests-2.26.0
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.8.2
#     Uninstalling pydantic-1.8.2:
#       Successfully uninstalled pydantic-1.8.2
#   Attempting uninstall: preshed
#     Found existing installation: preshed 3.0.6
#     Uninstalling preshed-3.0.6:
#       Successfully uninstalled preshed-3.0.6
#   Attempting uninstall: Jinja2
#     Found existing installation: Jinja2 3.0.3
#     Uninstalling Jinja2-3.0.3:
#       Successfully uninstalled Jinja2-3.0.3
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 4.8.2
#     Uninstalling importlib-metadata-4.8.2:
#       Successfully uninstalled importlib-metadata-4.8.2
#   Attempting uninstall: blis
#     Found existing installation: blis 0.7.6
#     Uninstalling blis-0.7.6:
#       Successfully uninstalled blis-0.7.6
#   Attempting uninstall: pathy
#     Found existing installation: pathy 0.6.1
#     Uninstalling pathy-0.6.1:
#       Successfully uninstalled pathy-0.6.1
#   Attempting uninstall: aiohttp
#     Found existing installation: aiohttp 3.8.1
#     Uninstalling aiohttp-3.8.1:
#       Successfully uninstalled aiohttp-3.8.1
#   Attempting uninstall: thinc
#     Found existing installation: thinc 8.0.15
#     Uninstalling thinc-8.0.15:
#       Successfully uninstalled thinc-8.0.15
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.2.3
#     Uninstalling spacy-3.2.3:
#       Successfully uninstalled spacy-3.2.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# anaconda-project 0.10.2 requires ruamel-yaml, which is not installed.
# sagemaker 2.116.0 requires importlib-metadata<5.0,>=1.4.0, but you have importlib-metadata 5.0.0 which is incompatible.
# docker-compose 1.29.2 requires PyYAML<6,>=3.10, but you have pyyaml 6.0 which is incompatible.
# boto3 1.26.6 requires botocore<1.30.0,>=1.29.6, but you have botocore 1.24.19 which is incompatible.
# awscli 1.27.6 requires botocore==1.29.6, but you have botocore 1.24.19 which is incompatible.
# awscli 1.27.6 requires PyYAML<5.5,>=3.10, but you have pyyaml 6.0 which is incompatible.
# awscli 1.27.6 requires rsa<4.8,>=3.1.2, but you have rsa 4.9 which is incompatible.
# aiobotocore 2.0.1 requires botocore<1.22.9,>=1.22.8, but you have botocore 1.24.19 which is incompatible.
# Successfully installed GitPython-3.1.27 Jinja2-3.1.2 Markdown-3.4.1 MarkupSafe-2.1.1 PyMuPDF-1.20.2 PyYAML-6.0 Werkzeug-2.2.2 absl-py-1.2.0 aiohttp-3.8.3 async-timeout-4.0.2 attrs-22.1.0 blis-0.7.8 cachetools-5.2.0 catalogue-2.0.8 certifi-2022.9.24 charset-normalizer-2.1.1 click-8.1.3 confection-0.0.2 docker-pycreds-0.4.0 en-core-web-sm-3.4.0 feedparser-6.0.10 filelock-3.8.0 frozenlist-1.3.1 fsspec-2022.8.2 gitdb-4.0.9 google-auth-2.12.0 google-auth-oauthlib-0.4.6 grpcio-1.49.1 huggingface-hub-0.10.0 idna-3.4 importlib-metadata-5.0.0 multidict-6.0.2 murmurhash-1.0.8 numpy-1.23.3 oauthlib-3.2.1 pathy-0.6.2 preshed-3.0.7 promise-2.3 protobuf-3.19.6 psutil-5.9.2 pyDeprecate-0.3.2 pyasn1-modules-0.2.8 pydantic-1.9.2 pyparsing-3.0.9 pytorch-lightning-1.7.7 regex-2022.9.13 requests-2.28.1 requests-oauthlib-1.3.1 rsa-4.9 scipy-1.9.1 sentry-sdk-1.9.9 setproctitle-1.3.2 sgmllib3k-1.0.0 shortuuid-1.0.9 smmap-5.0.0 spacy-3.4.1 spacy-legacy-3.0.10 spacy-loggers-1.0.3 srsly-2.4.4 tensorboard-2.10.1 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 thinc-8.1.2 tokenizers-0.12.1 torchmetrics-0.9.3 tqdm-4.64.1 transformers-4.22.2 typer-0.4.2 typing_extensions-4.3.0 urllib3-1.26.12 wandb-0.13.3 wasabi-0.10.1 yarl-1.8.1 zipp-3.8.1

# %%
# !HOROVOD_WITH_PYTORCH=1 pip install --no-cache-dir horovod[pytorch]
# Out:
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Requirement already satisfied: horovod[pytorch] in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (0.23.0)
# Requirement already satisfied: cffi>=1.4.0 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from horovod[pytorch]) (1.15.0)
# Requirement already satisfied: psutil in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from horovod[pytorch]) (5.9.2)
# Requirement already satisfied: pyyaml in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from horovod[pytorch]) (6.0)
# Requirement already satisfied: cloudpickle in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from horovod[pytorch]) (2.0.0)
# Requirement already satisfied: pytorch-lightning in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from horovod[pytorch]) (1.7.7)
# Requirement already satisfied: torch in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from horovod[pytorch]) (1.10.0)
# Requirement already satisfied: pycparser in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from cffi>=1.4.0->horovod[pytorch]) (2.21)
# Requirement already satisfied: fsspec[http]!=2021.06.0,>=2021.05.0 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from pytorch-lightning->horovod[pytorch]) (2022.8.2)
# Requirement already satisfied: numpy>=1.17.2 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from pytorch-lightning->horovod[pytorch]) (1.23.3)
# Requirement already satisfied: tensorboard>=2.9.1 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from pytorch-lightning->horovod[pytorch]) (2.10.1)
# Requirement already satisfied: pyDeprecate>=0.3.1 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from pytorch-lightning->horovod[pytorch]) (0.3.2)
# Requirement already satisfied: tqdm>=4.57.0 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from pytorch-lightning->horovod[pytorch]) (4.64.1)
# Requirement already satisfied: torchmetrics>=0.7.0 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from pytorch-lightning->horovod[pytorch]) (0.9.3)
# Requirement already satisfied: packaging>=17.0 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from pytorch-lightning->horovod[pytorch]) (21.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from pytorch-lightning->horovod[pytorch]) (4.3.0)
# Requirement already satisfied: requests in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning->horovod[pytorch]) (2.28.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning->horovod[pytorch]) (3.8.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from packaging>=17.0->pytorch-lightning->horovod[pytorch]) (3.0.9)
# Requirement already satisfied: absl-py>=0.4 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from tensorboard>=2.9.1->pytorch-lightning->horovod[pytorch]) (1.2.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from tensorboard>=2.9.1->pytorch-lightning->horovod[pytorch]) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from tensorboard>=2.9.1->pytorch-lightning->horovod[pytorch]) (3.4.1)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from tensorboard>=2.9.1->pytorch-lightning->horovod[pytorch]) (3.19.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from tensorboard>=2.9.1->pytorch-lightning->horovod[pytorch]) (2.12.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from tensorboard>=2.9.1->pytorch-lightning->horovod[pytorch]) (2.2.2)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from tensorboard>=2.9.1->pytorch-lightning->horovod[pytorch]) (0.6.1)
# Requirement already satisfied: wheel>=0.26 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from tensorboard>=2.9.1->pytorch-lightning->horovod[pytorch]) (0.37.0)
# Requirement already satisfied: grpcio>=1.24.3 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from tensorboard>=2.9.1->pytorch-lightning->horovod[pytorch]) (1.49.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from tensorboard>=2.9.1->pytorch-lightning->horovod[pytorch]) (1.8.1)
# Requirement already satisfied: setuptools>=41.0.0 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from tensorboard>=2.9.1->pytorch-lightning->horovod[pytorch]) (59.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning->horovod[pytorch]) (22.1.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning->horovod[pytorch]) (4.0.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning->horovod[pytorch]) (1.3.1)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning->horovod[pytorch]) (2.1.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning->horovod[pytorch]) (6.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning->horovod[pytorch]) (1.8.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning->horovod[pytorch]) (1.2.0)
# Requirement already satisfied: six>=1.9.0 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch-lightning->horovod[pytorch]) (1.16.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch-lightning->horovod[pytorch]) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch-lightning->horovod[pytorch]) (5.2.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch-lightning->horovod[pytorch]) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.9.1->pytorch-lightning->horovod[pytorch]) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from markdown>=2.6.8->tensorboard>=2.9.1->pytorch-lightning->horovod[pytorch]) (5.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning->horovod[pytorch]) (1.26.12)
# Requirement already satisfied: idna<4,>=2.5 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning->horovod[pytorch]) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning->horovod[pytorch]) (2022.9.24)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->pytorch-lightning->horovod[pytorch]) (2.1.1)
# Requirement already satisfied: zipp>=0.5 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard>=2.9.1->pytorch-lightning->horovod[pytorch]) (3.8.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch-lightning->horovod[pytorch]) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.9.1->pytorch-lightning->horovod[pytorch]) (3.2.1)

# %%
# !python train.py
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# Moving 0 files to the new cache system
# 0it [00:00, ?it/s]
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# GPU available: True (cuda), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages/pytorch_lightning/trainer/trainer.py:1764: PossibleUserWarning: GPU available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='gpu', devices=1)`.
#   rank_zero_warn(
# Missing logger folder: /home/ec2-user/SageMaker/arxiv_hunter/lightning_logs
#
#   | Name               | Type      | Params
# -------------------------------------------------
# 0 | query_encoder      | BertModel | 109 M
# 1 | passage_encoder    | BertModel | 109 M
# 2 | fc_query           | Linear    | 98.4 K
# 3 | fc_passage         | Linear    | 98.4 K
# 4 | layer_norm_query   | LayerNorm | 256
# 5 | layer_norm_passage | LayerNorm | 256
# 6 | dropout            | Dropout   | 0
# -------------------------------------------------
# 109 M     Trainable params
# 109 M     Non-trainable params
# 219 M     Total params
# 876.651   Total estimated model params size (MB)
# Epoch 0: : 170it [13:02,  4.61s/it, loss=17, v_num=0]
